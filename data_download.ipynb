# %%
pwd
# Out:
# '/Users/sts/Desktop/galvanize/city_bike'

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.style.use('ggplot')

import warnings
warnings.filterwarnings('ignore')

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
# NYC march 2020 data
feb20 = pd.read_csv('data/202002-citibike-tripdata.csv')
feb20.tail(3)
feb20.shape # (1048575, 15)
# Out:
#          tripduration      starttime       stoptime  start station id  \
# 1048572           678  2/27/20 12:08  2/27/20 12:19              3068
# 1048573           180  2/27/20 12:08  2/27/20 12:11              3680
# 1048574           358  2/27/20 12:08  2/27/20 12:14               437
#
#               start station name  start station latitude  \
# 1048572   Humboldt St & Varet St               40.703172
# 1048573          E 43 St & 5 Ave               40.754121
# 1048574  Macon St & Nostrand Ave               40.680983
#
#          start station longitude  end station id  \
# 1048572               -73.940636             539
# 1048573               -73.980252             485
# 1048574               -73.950048            3043
#
#                        end station name  end station latitude  \
# 1048572  Metropolitan Ave & Bedford Ave             40.715348
# 1048573                 W 37 St & 5 Ave             40.750380
# ...

# %%
# # df for all data
# df = pd.read_csv('data/202003-citibike-tripdata.csv')
# df.head(3)
# df.shape # (1048575, 15)

# %%
# NYC feb 2020 data
mar20 = pd.read_csv('data/202003-citibike-tripdata.csv')
mar20.head(1)
mar20.shape # (1048575, 15)
mar20.tail(1)
# Out:
#    tripduration    starttime     stoptime  start station id  \
# 0          1589  3/1/20 0:00  3/1/20 0:26               224
#
#       start station name  start station latitude  start station longitude  \
# 0  Spruce St & Nassau St               40.711464               -74.005524
#
#    end station id             end station name  end station latitude  \
# 0            3574  Prospect Pl & Underhill Ave             40.676969
#
#    end station longitude  bikeid    usertype  birth year  gender
# 0              -73.96579   16214  Subscriber        1980       1
# (1048575, 15)
#          tripduration      starttime       stoptime  start station id  \
# 1048574           593  3/30/20 16:52  3/30/20 17:02              3307
#
#              start station name  start station latitude  \
# 1048574  West End Ave & W 94 St               40.794165
#
#          start station longitude  end station id  end station name  \
# 1048574               -73.974124             422  W 59 St & 10 Ave
#
# ...

# %%
# NYC jan 2020 data
jan20 = pd.read_csv('data/202001-citibike-tripdata.csv')
jan20.shape # (1048575, 15)
jan20.head(1)
jan20.tail(3)
# Out:
# (1048575, 15)
#    tripduration    starttime     stoptime  start station id  \
# 0           789  1/1/20 0:00  1/1/20 0:14               504
#
#   start station name  start station latitude  start station longitude  \
# 0    1 Ave & E 16 St               40.732219               -73.981656
#
#    end station id       end station name  end station latitude  \
# 0             307  Canal St & Rutgers St             40.714275
#
#    end station longitude  bikeid    usertype  birth year  gender
# 0               -73.9899   30326  Subscriber        1992       1
#          tripduration      starttime       stoptime  start station id  \
# 1048572           319  1/27/20 20:52  1/27/20 20:58              3357
# 1048573           810  1/27/20 20:52  1/27/20 21:06              3359
# 1048574          2392  1/27/20 20:52  1/27/20 21:32               319
#
#                start station name  start station latitude  \
# 1048572  W 106 St & Amsterdam Ave               40.800836
# ...

# %%
# NYC Dec 2019 data
dec19 = pd.read_csv('data/201912-citibike-tripdata.csv')
print(dec19.shape) # (955210, 15)
print(dec19.info())
dec19.head(1)
# Out:
# (955210, 15)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 955210 entries, 0 to 955209
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   tripduration             955210 non-null  int64
#  1   starttime                955210 non-null  object
#  2   stoptime                 955210 non-null  object
#  3   start station id         955210 non-null  int64
#  4   start station name       955210 non-null  object
#  5   start station latitude   955210 non-null  float64
#  6   start station longitude  955210 non-null  float64
#  7   end station id           955210 non-null  int64
#  8   end station name         955210 non-null  object
#  9   end station latitude     955210 non-null  float64
#  10  end station longitude    955210 non-null  float64
#  11  bikeid                   955210 non-null  int64
#  12  usertype                 955210 non-null  object
# ...

# %%
# NYC nov 2019 data
nov19 = pd.read_csv('data/201911-citibike-tripdata.csv')
print(nov19.shape) # (1048575, 15)
print(nov19.info())
nov19.head(1)
# Out:
# (1048575, 15)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   tripduration             1048575 non-null  int64
#  1   starttime                1048575 non-null  object
#  2   stoptime                 1048575 non-null  object
#  3   start station id         1048575 non-null  int64
#  4   start station name       1048575 non-null  object
#  5   start station latitude   1048575 non-null  float64
#  6   start station longitude  1048575 non-null  float64
#  7   end station id           1048575 non-null  int64
#  8   end station name         1048575 non-null  object
#  9   end station latitude     1048575 non-null  float64
#  10  end station longitude    1048575 non-null  float64
#  11  bikeid                   1048575 non-null  int64
#  12  usertype                 1048575 non-null  object
# ...

# %%
# NYC oct 2019 data
oct19 = pd.read_csv('data/201910-citibike-tripdata.csv')
print(oct19.shape) # (1048575, 15)
print(oct19.info())
oct19.head(1)
# Out:
# (1048575, 15)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   tripduration             1048575 non-null  int64
#  1   starttime                1048575 non-null  object
#  2   stoptime                 1048575 non-null  object
#  3   start station id         1048575 non-null  int64
#  4   start station name       1048575 non-null  object
#  5   start station latitude   1048575 non-null  float64
#  6   start station longitude  1048575 non-null  float64
#  7   end station id           1048575 non-null  int64
#  8   end station name         1048575 non-null  object
#  9   end station latitude     1048575 non-null  float64
#  10  end station longitude    1048575 non-null  float64
#  11  bikeid                   1048575 non-null  int64
#  12  usertype                 1048575 non-null  object
# ...

# %%
# NYC sept 2019 data
sept19 = pd.read_csv('data/201909-citibike-tripdata.csv')
print(sept19.shape) # (1048575, 15)
print(sept19.info())
sept19.head(1)
# Out:
# (1048575, 15)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   tripduration             1048575 non-null  int64
#  1   starttime                1048575 non-null  object
#  2   stoptime                 1048575 non-null  object
#  3   start station id         1048575 non-null  int64
#  4   start station name       1048575 non-null  object
#  5   start station latitude   1048575 non-null  float64
#  6   start station longitude  1048575 non-null  float64
#  7   end station id           1048575 non-null  int64
#  8   end station name         1048575 non-null  object
#  9   end station latitude     1048575 non-null  float64
#  10  end station longitude    1048575 non-null  float64
#  11  bikeid                   1048575 non-null  int64
#  12  usertype                 1048575 non-null  object
# ...

# %%
# NYC aug 2019 data
aug19 = pd.read_csv('data/201908-citibike-tripdata.csv')
print(aug19.shape) # (1048575, 15)
print(aug19.info())
aug19.head(1)
# Out:
# (1048575, 15)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   tripduration             1048575 non-null  int64
#  1   starttime                1048575 non-null  object
#  2   stoptime                 1048575 non-null  object
#  3   start station id         1048549 non-null  float64
#  4   start station name       1048549 non-null  object
#  5   start station latitude   1048575 non-null  float64
#  6   start station longitude  1048575 non-null  float64
#  7   end station id           1048549 non-null  float64
#  8   end station name         1048549 non-null  object
#  9   end station latitude     1048575 non-null  float64
#  10  end station longitude    1048575 non-null  float64
#  11  bikeid                   1048575 non-null  int64
#  12  usertype                 1048575 non-null  object
# ...

# %%
march18 = pd.read_csv('data/201803-citibike-tripdata.csv')

# %%
july19 = pd.read_csv('data/2019907-citibike-tripdata.csv')
july19.shape # (1048575, 15)
july19.head()
july19.tail()
# Out:
# (1048575, 23)
#    Unnamed: 0  tripduration            starttime     stoptime  \
# 0           0           500  2019-07-01 00:33:00  7/1/18 0:42
# 1           1           455  2019-07-01 02:06:00  7/1/18 2:14
# 2           2          1080  2019-07-01 02:09:00  7/1/18 2:27
# 3           3           632  2019-07-01 02:55:00  7/1/18 3:05
# 4           4          1676  2019-07-01 03:24:00  7/1/18 3:52
#
#    start station id start station name  start station latitude  \
# 0                72   W 52 St & 11 Ave               40.767272
# 1                72   W 52 St & 11 Ave               40.767272
# 2                72   W 52 St & 11 Ave               40.767272
# 3                72   W 52 St & 11 Ave               40.767272
# 4                72   W 52 St & 11 Ave               40.767272
#
#    start station longitude  end station id    end station name  ...  \
# 0               -73.993929            3236  W 42 St & Dyer Ave  ...
# ...

# %%
# NYC jun 2019 data
jun19 = pd.read_csv('data/201906-citibike-tripdata.csv')
print(jun19.shape) # (1048575, 15)
print(jun19.info())
jun19.head(1)
# Out:
# (1048575, 15)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   tripduration             1048575 non-null  int64
#  1   starttime                1048575 non-null  object
#  2   stoptime                 1048575 non-null  object
#  3   start station id         1048575 non-null  int64
#  4   start station name       1048575 non-null  object
#  5   start station latitude   1048575 non-null  float64
#  6   start station longitude  1048575 non-null  float64
#  7   end station id           1048575 non-null  int64
#  8   end station name         1048575 non-null  object
#  9   end station latitude     1048575 non-null  float64
#  10  end station longitude    1048575 non-null  float64
#  11  bikeid                   1048575 non-null  int64
#  12  usertype                 1048575 non-null  object
# ...

# %%
# NYC may 2019 data
may19 = pd.read_csv('data/201905-citibike-tripdata.csv')
print(may19.shape) # (1048575, 15)
print(may19.info())
may19.head(1)
may19.tail(4)  # apr 18
# Out:
# (1048575, 15)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   tripduration             1048575 non-null  int64
#  1   starttime                1048575 non-null  object
#  2   stoptime                 1048575 non-null  object
#  3   start station id         1048575 non-null  int64
#  4   start station name       1048575 non-null  object
#  5   start station latitude   1048575 non-null  float64
#  6   start station longitude  1048575 non-null  float64
#  7   end station id           1048575 non-null  int64
#  8   end station name         1048575 non-null  object
#  9   end station latitude     1048575 non-null  float64
#  10  end station longitude    1048575 non-null  float64
#  11  bikeid                   1048575 non-null  int64
#  12  usertype                 1048575 non-null  object
# ...

# %%
# NYC apr 2019 data
apr19 = pd.read_csv('data/201904-citibike-tripdata.csv')
print(apr19.shape) # (1048575, 15)
print(apr19.info())
apr19.head(4)
apr19.tail(4)  # apr 18
# Out:
# (1048575, 15)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   tripduration             1048575 non-null  int64
#  1   starttime                1048575 non-null  object
#  2   stoptime                 1048575 non-null  object
#  3   start station id         1048575 non-null  int64
#  4   start station name       1048575 non-null  object
#  5   start station latitude   1048575 non-null  float64
#  6   start station longitude  1048575 non-null  float64
#  7   end station id           1048575 non-null  int64
#  8   end station name         1048575 non-null  object
#  9   end station latitude     1048575 non-null  float64
#  10  end station longitude    1048575 non-null  float64
#  11  bikeid                   1048575 non-null  int64
#  12  usertype                 1048575 non-null  object
# ...

# %%
# NYC mar 2019 data
march19 = pd.read_csv('data/201903-citibike-tripdata.csv')
print(march19.shape) # (1048575, 15)
print(march19.info())
march19.head(4)
march19.tail(4)  # apr 18
# Out:
# (1048575, 15)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   tripduration             1048575 non-null  int64
#  1   starttime                1048575 non-null  object
#  2   stoptime                 1048575 non-null  object
#  3   start station id         1048569 non-null  float64
#  4   start station name       1048569 non-null  object
#  5   start station latitude   1048575 non-null  float64
#  6   start station longitude  1048575 non-null  float64
#  7   end station id           1048569 non-null  float64
#  8   end station name         1048569 non-null  object
#  9   end station latitude     1048575 non-null  float64
#  10  end station longitude    1048575 non-null  float64
#  11  bikeid                   1048575 non-null  int64
#  12  usertype                 1048575 non-null  object
# ...

# %%
# months = ['mar20,'feb20', 'jan20', 'dec19', 'nov19', 'oct19', 'sept19', 
#           'aug19', 'july19', 'jun19', 'may19', 'apr19']

# %% [markdown]
# # Concatinated DataFrame for last 12 months
# * ## Size: 12489535, Rows; 15 Columns

# %%
months = [march19,feb20, jan20, dec19, nov19, oct19, sept19, 
          aug19, july19, jun19, may19, apr19]

df = pd.concat(months)

df.shape # (11498214, 15)
# Out:
# (12489535, 23)

# %%
df.shape # (11498214, 15)
df.info()
df.columns
df.describe()
# Out:
# (12489535, 23)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12489535 entries, 0 to 1048574
# Data columns (total 23 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   tripduration             int64
#  1   starttime                object
#  2   stoptime                 object
#  3   start station id         float64
#  4   start station name       object
#  5   start station latitude   float64
#  6   start station longitude  float64
#  7   end station id           float64
#  8   end station name         object
#  9   end station latitude     float64
#  10  end station longitude    float64
#  11  bikeid                   int64
#  12  usertype                 object
#  13  birth year               int64
#  14  gender                   int64
#  15  Unnamed: 0               float64
#  16  dates                    object
#  17  hour                     float64
#  18  Day                      float64
#  19  week                     float64
# ...

# %%
# find top bike station to analyze

# %%
# Top end/stop station 
stop_stations = df.groupby('end station name').count()['start station id'].sort_values(ascending = False)
stop_stations.head()
# Out:
# end station name
# Pershing Square North    98892
# E 17 St & Broadway       81280
# Broadway & E 22 St       77132
# 8 Ave & W 31 St          74716
# Broadway & E 14 St       70535
# Name: start station id, dtype: int64

# %%
# Top end/stop station 
stop_stations = df.groupby('end station name').count()['start station id'].sort_values(ascending = False)
stop_stations.head(10)
# Out:
# end station name
# Pershing Square North            98892
# E 17 St & Broadway               81280
# Broadway & E 22 St               77132
# 8 Ave & W 31 St                  74716
# Broadway & E 14 St               70535
# W 21 St & 6 Ave                  70333
# West St & Chambers St            69395
# W 20 St & 11 Ave                 62314
# Lafayette St & E 8 St            61934
# Christopher St & Greenwich St    61764
# Name: start station id, dtype: int64

# %%
# total number of bike stations : 899

df['end station id'].count() # 1048575
# df['end station id'].unique()#.sort_values(ascending = False) #
df['end station id'].nunique() # 899
# Out:
# 12489503
# 1000

# %%
# total number of bikes 14874

df['bikeid'].count() # 1048575
df['bikeid'].unique().max()#.sort_values(ascending = False) #
df['bikeid'].nunique() # 14874
# Out:
# 12489535
# 42643
# 19876

# %%
# date time to data_time format 
timestamp = pd.to_datetime(df['starttime'])

df['date'] = timestamp.dt.date
df['hour'] = timestamp.dt.hour
df['Day'] = timestamp.dt.day  # 1-30
# df['week'] = timestamp.dt.week # numbers of week 1 - 14 
# df['dayofweek'] = timestamp.dt.dayofweek # 0, 6 days 
df['weekday'] = timestamp.dt.weekday  # 0-6 days 
df['day of year'] = timestamp.dt.dayofyear # day by year 1-90

# %%
# create day of month column 
df['day of month'] = df['starttime'].apply(lambda x: x.split()[0])

# create hh:mm column time 
df['start time'] = df['starttime'].apply(lambda x: x.split()[1])
df['stop time'] = df['stoptime'].apply(lambda x: x.split()[1])

# %%
df.head(1)
# Out:
#    tripduration    starttime     stoptime  start station id  \
# 0          1463  3/1/19 0:00  3/1/19 0:24             319.0
#
#      start station name  start station latitude  start station longitude  \
# 0  Fulton St & Broadway               40.711066               -74.009447
#
#    end station id             end station name  end station latitude  ...  \
# 0           347.0  Greenwich St & W Houston St             40.728846  ...
#
#    hour  Day week  month  weekday  day of year        date  day of month  \
# 0     0    1  NaN    NaN        4           60  2019-03-01        3/1/19
#
#    start time  stop time
# 0        0:00       0:24
#
# [1 rows x 27 columns]

# %%
# Create different new columns for hour, each month and year-month from given Date and time columns 

hours = df['start time'].str.split(":", expand = True)

df['hour'] = hours[0]

# make 01 02, ... in hour to sort 
df['hour'] = df['hour'].apply(lambda x: x.zfill(2))

months = df['day of month'].str.split("/", expand = True)
df['month'] = months[0]
df['month'] = df['month'].apply(lambda x: x.zfill(2))

# %%
# group by day of the month 
# daily_count = df.groupby(['day of month','start station name']).count()['start station id'].sort_values(ascending = False)
daily_count = df.groupby('day of month').count()['start station id'].sort_values(ascending = False)

daily_count.head(4)
# Out:
# day of month
# 9/11/19    90448
# 9/5/19     89656
# 8/1/19     87703
# 9/13/19    87636
# Name: start station id, dtype: int64

# %%
# trip duration time in minute; seconds given 
df['Trip in Minutes'] = df['tripduration'].apply(lambda x: x/60.0).round(0)
# df

# %%
df['age'] = df['birth year'].apply(lambda x: 2019 - x)

# %%
# user type: Subscriber & Customer[non-subscriber] 16.87 ratio
# percentage: 14.43 % non-subscriber  

df.usertype.unique() # array(['Subscriber', 'Customer'], dtype=object)
subs = df[df.usertype == 'Subscriber'].count() # 897222
cust = df[df.usertype == 'Customer'].count() # 151353
user_perc = cust/(subs+cust)
# user_perc

# %%
# df.describe()

# %%
features = ['start station name', 'end station name','usertype','gender', 
            'day of month', 'start time', 'stop time','Trip in Minutes', 'age']

# %%
df.groupby('day of year').nunique()

# %%
top1 = df[df['start station name'] == 'Pershing Square North']

# %%
top1.to_csv('top1_bike_station.csv')

# %%
top5 = df.loc[df['start station name'].isin(['Pershing Square North', 'E 17 St & Broadway', '8 Ave & W 31 St', 'Broadway & E 22 St', 'Broadway & E 14 St'])]

# %%
# top start station
top5.to_csv('top5_bike_stations.csv')
